# %% [markdown]
# ### Mr. Tuấn Anh

# %%
import numpy as np
x = np.random.randint(1,100,100)
print(x)
print(type(x))
# Out:
# [99 75 18 39 48 25 70 94 33 14 13 78 90 63  8 37 53 38 43 11 25 87 79 28
#  45 52 59 42  5 19 26 32 92 86 49 51 77 82 43 38 10 58 52 53 18 98 54 59
#  64 10 45 24 95 54 63 81  3 72 18 31 72 79 85 86 29 14  9 33 69 41  7 80
#  61  5 98 88 99 32 91  3 23 31  2 49 82 20 11 80  6 63 49 41 63 27 48  4
#  15 72 98 29]
# <class 'numpy.ndarray'>

# %%
import matplotlib.pyplot as plt
plt.plot(x)
plt.title('Đồ thị gốc X')
plt.show()

# %%
def find_max(ds):
    max_value = ds[0] 
    for num in ds:
     if num > max_value:
        max_value = num
    return max_value
list_data = x 
max_value_data = find_max(list_data)
print("Giá trị lớn nhất trong dãy số là:", max_value_data)
# Out:
# Giá trị lớn nhất trong dãy số là: 99

# %%
a = max(list_data)
print(a)
# Out:
# 99

# %%
def find_min(ds):
    min_value = ds[0] 
    for num in ds:
     if num < min_value:
        min_value = num
    return min_value
min_value_data = find_min(list_data)
print("Giá trị nho nhất trong dãy số là:", min_value_data)
# Out:
# Giá trị nho nhất trong dãy số là: 2

# %%
def normalization(list_data):
    normal_list = []
    for i in list_data:
        a = (i-min_value_data)/(max_value_data - min_value_data)
        normal_list.append(a)
    return normal_list
a = normalization(list_data)
print(a)
# Out:
# [1.0, 0.7525773195876289, 0.16494845360824742, 0.38144329896907214, 0.4742268041237113, 0.23711340206185566, 0.7010309278350515, 0.9484536082474226, 0.31958762886597936, 0.12371134020618557, 0.1134020618556701, 0.7835051546391752, 0.9072164948453608, 0.6288659793814433, 0.061855670103092786, 0.36082474226804123, 0.5257731958762887, 0.3711340206185567, 0.422680412371134, 0.09278350515463918, 0.23711340206185566, 0.8762886597938144, 0.7938144329896907, 0.26804123711340205, 0.44329896907216493, 0.5154639175257731, 0.5876288659793815, 0.41237113402061853, 0.030927835051546393, 0.17525773195876287, 0.24742268041237114, 0.30927835051546393, 0.9278350515463918, 0.865979381443299, 0.4845360824742268, 0.5051546391752577, 0.7731958762886598, 0.8247422680412371, 0.422680412371134, 0.3711340206185567, 0.08247422680412371, 0.5773195876288659, 0.5154639175257731, 0.5257731958762887, 0.16494845360824742, 0.9896907216494846, 0.5360824742268041, 0.5876288659793815, 0.6391752577319587, 0.08247422680412371, 0.44329896907216493, 0.2268041237113402, 0.9587628865979382, 0.5360824742268041, 0.6288659793814433, 0.8144329896907216, 0.010309278350515464, 0.7216494845360825, 0.16494845360824742, 0.29896907216494845, 0.7216494845360825, 0.7938144329896907, 0.8556701030927835, 0.865979381443299, 0.27835051546391754, 0.12371134020618557, 0.07216494845360824, 0.31958762886597936, 0.6907216494845361, 0.4020618556701031, 0.05154639175257732, 0.8041237113402062, 0.6082474226804123, 0.030927835051546393, 0.9896907216494846, 0.8865979381443299, 1.0, 0.30927835051546393, 0.9175257731958762, 0.010309278350515464, 0.21649484536082475, 0.29896907216494845, 0.0, 0.4845360824742268, 0.8247422680412371, 0.18556701030927836, 0.09278350515463918, 0.8041237113402062, 0.041237113402061855, 0.6288659793814433, 0.4845360824742268, 0.4020618556701031, 0.6288659793814433, 0.25773195876288657, 0.4742268041237113, 0.020618556701030927, 0.13402061855670103, 0.7216494845360825, 0.9896907216494846, 0.27835051546391754]

# %%
print(type(list_data))
# Out:
# <class 'numpy.ndarray'>

# %%
# Tính normalization

list_data_nor = (list_data-min_value_data)/(max_value_data - min_value_data)
print(list_data_nor)
# Out:
# [1.         0.75257732 0.16494845 0.3814433  0.4742268  0.2371134
#  0.70103093 0.94845361 0.31958763 0.12371134 0.11340206 0.78350515
#  0.90721649 0.62886598 0.06185567 0.36082474 0.5257732  0.37113402
#  0.42268041 0.09278351 0.2371134  0.87628866 0.79381443 0.26804124
#  0.44329897 0.51546392 0.58762887 0.41237113 0.03092784 0.17525773
#  0.24742268 0.30927835 0.92783505 0.86597938 0.48453608 0.50515464
#  0.77319588 0.82474227 0.42268041 0.37113402 0.08247423 0.57731959
#  0.51546392 0.5257732  0.16494845 0.98969072 0.53608247 0.58762887
#  0.63917526 0.08247423 0.44329897 0.22680412 0.95876289 0.53608247
#  0.62886598 0.81443299 0.01030928 0.72164948 0.16494845 0.29896907
#  0.72164948 0.79381443 0.8556701  0.86597938 0.27835052 0.12371134
#  0.07216495 0.31958763 0.69072165 0.40206186 0.05154639 0.80412371
#  0.60824742 0.03092784 0.98969072 0.88659794 1.         0.30927835
#  0.91752577 0.01030928 0.21649485 0.29896907 0.         0.48453608
#  0.82474227 0.18556701 0.09278351 0.80412371 0.04123711 0.62886598
#  0.48453608 0.40206186 0.62886598 0.25773196 0.4742268  0.02061856
#  0.13402062 0.72164948 0.98969072 0.27835052]

# %%
# Đồ thị sau khi Normalization

plt.plot(list_data_nor)
plt.title('X sau khi Normalization')
plt.show()

# %% [markdown]
# ### Ms. Hong

# %%
# Cách 3: tính mean

def tinh_mean_c1(listx):
    sum =  0
    for i in listx:
        sum += i 
    meanx = sum/len(listx)    
    return meanx

tinh_mean_c1(x)
# Out:
# 48.22

# %%
# Cách 2: tính mean

def tinh_mean_c2(listx):
    sum =  np.sum(listx)
    meanx = sum/len(listx)    
    return meanx

tinh_mean_c2(x)
# Out:
# 48.22

# %%
# Cách 3: tính mean

def tinh_mean_c3(listx):
    sizex = np.size(listx)
    sum = np.sum(listx)
    # sum =  0
    # for i in listx:
    #     sum += i 
    meanx = sum/sizex    
    return meanx

tinh_mean_c3(x)
# Out:
# 48.22

# %% [markdown]
# ### Mr. Đào Anh

# %%
# Tính độ lệch chuẩn standard

def standard(data):
    size = np.size(data)
    y = np.sum((data - tinh_mean_c3(data))**2)
    z = y / size
    std = np.sqrt(z)

    return std

result = standard(x)
print(result)
# Out:
# 28.925621860212445

# %%
# Tính Standardization

def Standardization(data):
    Stand_data = (data - tinh_mean_c3(data))/standard(data)
    return Stand_data

result1 = Standardization(x)
result1
# Out:
# array([ 1.75553702,  0.92582279, -1.0447485 , -0.31874855, -0.00760571,
#        -0.80274852,  0.75296566,  1.58267989, -0.52617711, -1.1830342 ,
#        -1.21760563,  1.02953707,  1.44439418,  0.51096568, -1.39046276,
#        -0.3878914 ,  0.16525142, -0.35331998, -0.18046284, -1.28674848,
#        -0.80274852,  1.34067991,  1.0641085 , -0.69903424, -0.11131999,
#         0.13067999,  0.37267997, -0.21503427, -1.49417704, -1.01017707,
#        -0.76817709, -0.56074853,  1.51353704,  1.30610848,  0.02696571,
#         0.09610856,  0.99496564,  1.16782278, -0.18046284, -0.35331998,
#        -1.32131991,  0.33810855,  0.13067999,  0.16525142, -1.0447485 ,
#         1.72096559,  0.19982284,  0.37267997,  0.5455371 , -1.32131991,
#        -0.11131999, -0.83731994,  1.61725132,  0.19982284,  0.51096568,
#         1.13325135, -1.56331989,  0.82210851, -1.0447485 , -0.59531996,
#         0.82210851,  1.0641085 ,  1.27153705,  1.30610848, -0.66446281,
#        -1.1830342 , -1.35589133, -0.52617711,  0.71839424, -0.2496057 ,
#        -1.42503419,  1.09867992,  0.44182283, -1.49417704,  1.72096559,
#         1.37525133,  1.75553702, -0.56074853,  1.47896561, -1.56331989,
#        -0.87189137, -0.59531996, -1.59789132,  0.02696571,  1.16782278,
#        -0.97560565, -1.28674848,  1.09867992, -1.45960561,  0.51096568,
#         0.02696571, -0.2496057 ,  0.51096568, -0.73360566, -0.00760571,
#        -1.52874846, -1.14846278,  0.82210851,  1.72096559, -0.66446281])

# %%
# Đồ thị sau khi standardization

plt.plot(result1)
plt.title('X sau khi standardization')
plt.show()

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,3,1)
plt.plot(x)
plt.title('Đồ thị gốc X')

plt.subplot(1,3,2)
plt.plot(list_data_nor)
plt.title('Normalization')

plt.subplot(1,3,3)
plt.plot(result1)
plt.title('Standardization')
plt.show()

# %% [markdown]
# - Dữ liệu X sau khi Normalization : hình dạng đồ thị vẫn giống hình dạng của đồ thị gốc X. Tuy nhiên, giá trị trục Y được thu gọn theo công thức : $$X_{norm} = \frac{X_{i} - X_{min}}{X_{max} - X_{min}}$$
# >>>> Như đồ thị (2) trên ta có thể thấy: Sau khi Normalization, giá trị chỉ từ: 0 -> 1 (thay vì 0 -> 100).
#
# - Dữ liệu X sau khi Standardization : hình dạng đồ thị vẫn giống hình dạng của đồ thị gốc X. Tuy nhiên, giá trị trục Y được thu gọn theo công thức : $$z = \frac{x - \mu}{\sigma}$$
# >>>> Như đồ thị (3) trên ta có thể thấy: Sau khi Standardization, giá trị chỉ từ: ~2 -> 2 (thay vì 0 -> 100) và đối xứng qua trục X.
